# %% [markdown]
# # Pandas & Visualization

# %% [markdown]
# ### Task 1
# Write a Pandas program to select the rows where the score is missing, i.e. is NaN.
#
# Sample Python dictionary data and list labels:
# ```
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
# Expected Output:
#
# `Rows where score is missing:`
# |       | name  | score | attempts | qualify |
# |-------|--------|--------|----------|----------|
# | d     | James  | NaN    | 3        | no       |
# | h     | Laura  | NaN    | 1        | no       |

# %%
import pandas as pd
import numpy as np 

exam_data = {
    'name': ['Anastasia','Dima','Katherine','James','Emily','Michael','Matthew','Laura','Kevin','Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes','no','yes','no','no','yes','yes','no','no','yes']
}
labels = ['a','b','c','d','e','f','g','h','i','j']

df = pd.DataFrame(exam_data, index=labels)
print("Rows where score is missing:\n")
missing_score = df[df['score'].isna()]
print(missing_score)
# Out:
# Rows where score is missing:
#
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# ### Task 2
# Write a Pandas program to select the rows where number of attempts in the examination is less than 2 and score greater than 15.
#
# Sample Python dictionary data and list labels:
# ```
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# Expected Output:
# ```
# Number of attempts in the examination is less than 2 and score greater than 15 :
# name score attempts qualify
# j Jonas 19.0 1 yes
# ```

# %%
import pandas as pd
import numpy as np

exam_data = {
    'name': ['Anastasia','Dima','Katherine','James','Emily','Michael','Matthew','Laura','Kevin','Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes','no','yes','no','no','yes','yes','no','no','yes']
}

labels = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data, index=labels)
result = df[(df['attempts'] < 2) & (df['score'] > 15)]

print("Number of attempts in the examination is less than 2 and score greater than 15:\n")
print(result)
# Out:
# Number of attempts in the examination is less than 2 and score greater than 15:
#
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %% [markdown]
# ### Task 3
# Write a Pandas program to calculate the sum of the examination attempts by the students.
#
# Sample Python dictionary data and list labels:
# ```
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# Expected Output:
# ```
# Sum of the examination attempts by the students
# 19
# ```

# %%
import pandas as pd
import numpy as np
exam_data = {
    'name': ['Anastasia','Dima','Katherine','James','Emily','Michael','Matthew','Laura','Kevin','Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes','no','yes','no','no','yes','yes','no','no','yes']
}

labels = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data, index=labels)
total_attempts = df['attempts'].sum()

print("Sum of the examination attempts by the students:")
print(total_attempts)
# Out:
# Sum of the examination attempts by the students:
# 19

# %% [markdown]
# ### Task 4
# Write a Pandas program to replace the 'qualify' column contains the values 'yes' and 'no' with True and False. Save the data set after the modification as csv file
#
# Sample Python dictionary data and list labels:
# ```
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
# Expected Output:
# ```
# Replace the 'qualify' column contains the values 'yes' and 'no' with T
# rue and False:
# attempts name qualify score
# a 1 Anastasia True 12.5
# b 3 Dima False 9.0
# ......
# i 2 Kevin False 8.0
# j 1 Jonas True 19.0

# %%
import pandas as pd
import numpy as np

exam_data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}

labels = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data, index=labels)
df['qualify'] = df['qualify'].map({'yes': True, 'no': False})

print("Replace the 'qualify' column contains the values 'yes' and 'no' with True and False:\n")
print(df)

df.to_csv("modified_exam_data.csv")
# Out:
# Replace the 'qualify' column contains the values 'yes' and 'no' with True and False:
#
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %% [markdown]
# ### Task 5
# Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates(1-4-2020 to 30-9-2020).
#
# (alphabet_stock_data.csv)
# *Link: https://www.kaggle.com/datasets/anuragmishra2311/alphabet-stocks/data*
#
# Expected Output:
# ![image.png](attachment:55ebe7b9-81fd-40ea-bde3-0ab271b15690.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Alphabet Stock.csv")  

df['Date'] = pd.to_datetime(df['Date'])

start = "2020-04-01"
end = "2020-09-30"

filtered = df[(df['Date'] >= start) & (df['Date'] <= end)]

plt.figure(figsize=(10,6))
plt.plot(filtered['Date'], filtered['Close'], color='green')

plt.title("Stock prices of Alphabet Inc.,\n01-04-2020 to 30-09-2020")
plt.xlabel("Date")
plt.ylabel("$ price")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Task 6
# Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates (1-4-2020 to 30-9-2020).
# Save the plot as PDF on the desktop. ( alphabet_stock_data.csv)
#
# Expected Output:
# ![image.png](attachment:b799ba30-5467-47af-87e1-626caeb736e9.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Alphabet Stock.csv")   

df['Date'] = pd.to_datetime(df['Date'])


start = "2020-04-01"
end = "2020-09-30"

filtered = df[(df['Date'] >= start) & (df['Date'] <= end)]
plt.figure(figsize=(10,6))

plt.plot(filtered['Date'], filtered['Open'], label="Open", color='blue')
plt.plot(filtered['Date'], filtered['Close'], label="Close", color='orange')
plt.title("Opening/Closing stock prices of Alphabet Inc.,\n01-04-2020 to 30-09-2020")
plt.xlabel("Date")
plt.ylabel("$ price")
plt.xticks(rotation=45)
plt.legend()


plt.show()
plt.savefig("Alphabet_Stock_Prices.pdf")

# %% [markdown]
# ### Task 7
# Write a Pandas program to create a scatter plot of the trading volume/open stock prices of Alphabet Inc. stock between two specific dates (1-4-2020 to 30-9-2020). ( alphabet_stock_data.csv)
#
# Expected Output:
# ![image.png](attachment:dbe48a62-66a2-4f21-9bfb-73a0f90d69ef.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Alphabet Stock.csv")

df['Date'] = pd.to_datetime(df['Date'])


start = "2020-04-01"
end = "2020-09-30"

filtered = df[(df['Date'] >= start) & (df['Date'] <= end)]

plt.figure(figsize=(10,6))
plt.scatter(filtered['Open'], filtered['Volume'], color='blue')

plt.title("Trading Volume/Price of Alphabet Inc. stock,\n01-04-2020 to 30-09-2020")
plt.xlabel("Stock Price")
plt.ylabel("Trading Volume")

plt.grid(True, linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# ### Task 8
# Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates(1-4-2020 to 30-4-2020). (alphabet_stock_data.csv)
#
# Expected Output:
# ![image.png](attachment:0479eb40-a81b-432a-9ad3-f5cd84755aab.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Alphabet Stock.csv")

df['Date'] = pd.to_datetime(df['Date'])


start = "2020-04-01"
end = "2020-04-30"

april = df[(df['Date'] >= start) & (df['Date'] <= end)]
plt.figure(figsize=(10,6))
plt.hist(april['Open'], bins=10, orientation='horizontal',
         cumulative=True, color='steelblue', edgecolor='black')

plt.title("Opening stock prices of Alphabet Inc.\nFrom 01-04-2020 to 30-04-2020")
plt.xlabel("Frequency")
plt.ylabel("Open Price")

plt.show()

# %% [markdown]
# ### Task 9
#
# Write a Pandas program to draw a Box plot of volume (the amount of stock traded) of Alphabet Inc. In April (1-4-2020 to 30-4-2020). ( alphabet_stock_data.csv)
#
# Expected Output:
# ![image.png](attachment:f7c540bc-c432-47ca-b9d7-8ddff28a0a17.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Alphabet Stock.csv")
df['Date'] = pd.to_datetime(df['Date'])


start = "2020-04-01"
end = "2020-04-30"

april = df[(df['Date'] >= start) & (df['Date'] <= end)]
plt.figure(figsize=(10,6))
plt.boxplot(april['Volume'], vert=True)

plt.title("Volume of Alphabet Inc.\n01-04-2020 to 30-04-2020")
plt.ylabel("Volume")
plt.xlabel("Date")   
plt.show()

# %% [markdown]
# ### Task 10
# Write a Pandas program to print summary statistics for price column.
#
# (dimonds.csv)
# *Link: https://www.kaggle.com/datasets/nameeerafatima/diamondscsv*
#
# Expected Output:
# ![image.png](attachment:b54e07a6-8035-4ef7-890c-bbcd66d1a3a3.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("diamonds.csv.zip")

print("summary statistics :")
print(df['price'].describe())

plt.boxplot(df['price'])
plt.title("task 1")
plt.xlabel("price")
plt.show()
# Out:
# summary statistics :
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
